# %% [markdown]
# #### 1. User Login Check
# Problem Statement:
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"
#
# Requirements:
# Print "Login Successful" if both username and password match
# Otherwise print "Invalid Credentials"
#
# Real-World Application: Authentication systems

# %%
username = input("enter the username:")
password = int(input("enter password:"))
if(username == "admin" and password == 1234):
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# enter the username: admin
# enter password: 1234
# Login Successful

# %% [markdown]
# #### 2. Pass / Fail Analyzer
# Problem Statement:
# Analyze student results.
# marks = [45, 78, 90, 33, 60]
#
# Requirements:
# A student passes if marks ≥ 50
# Count the total number of pass students
# Count the total number of fail students
# Print the final result clearly
#
# Real-World Application: Academic evaluation systems

# %%
marks = [45,78,90,33,60]
l = 0
k = 0
for i in marks:
    if(i>=50):
        l = l + 1
    else:
        k = k + 1
print(f"total number of pass students are {l}")
print(f"total number of fail students are {k}")
# Out:
# total number of pass students are 3
# total number of fail students are 2

# %% [markdown]
# #### 3. Simple Data Cleaner
# Problem Statement:
# Clean and standardize user names.
# names = [" Alice ", "bob", " CHARLIE "]
#
# Requirements:
# Remove extra spaces
# Convert all names to lowercase
# Print the cleaned list
#
# Real-World Application: Data preprocessing before analysis

# %%
cleaned_names = []
names = [" Alice ", "bob", " CHARLIE "]

for name in names:
    cleaned_names.append(name.strip().lower())

print(cleaned_names)
# Out:
# ['alice', 'bob', 'charlie']

# %% [markdown]
# #### 4. Message Length Analyzer
# Problem Statement:
# Analyze message sizes.
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# Requirements:
# Print the length of each message
# Flag messages longer than 10 characters
#
# Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
for i in messages:
    length = len(i)
    print(f"length of message {i} is {length}")
    if(length > 10):
        print(f"length of {i} is longer than 10 characters")
# Out:
# length of message Hi is 2
# length of message Welcome to the platform is 23
# length of Welcome to the platform is longer than 10 characters
# length of message OK is 2

# %% [markdown]
# #### 5. Error Message Detector
# Problem Statement:
# Detect error messages from system logs.
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# Requirements:
# Count the number of "ERROR" entries
# Print the total error count
#
# Real-World Application: Monitoring and log analysis systems

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
count = 0

for log in logs:
    if log == "ERROR":
        print("error detected")
        count = count + 1
print(f"the number of errors detected is {count}")
# Out:
# error detected
# error detected
# the number of errors detected is 2
