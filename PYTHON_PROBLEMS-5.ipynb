# %% [markdown]
# # Problem 1: Social Media – Post Engagement Analyzer
# Problem Statement
# Create a function to analyze engagement on a social media post.
#
# ### Rules
#
# Calculate total likes
#
# If Total Likes ≥ 1000 → Viral Post
#
# Otherwise → Normal Engagement
#
# ### Real-Time Use
#
# Social media analytics platforms
#
# Marketing dashboards
#
# ### Hint
#
# Use function,
# Use loop for calculations
#
# ### Expected Output Format
# Total Likes: 1050
#
# Post Status: Viral Post

# %%
def post_engage(likes):
    if likes >= 1000:
        print(f"total likes: {likes}")
        print("Post status: Viral Post")
    else:
        print(f"total likes: {likes}")
        print("Post status: Normal Engagement")
post_engage(334)
# Out:
# total likes: 334
# Post status: Normal Engagement

# %% [markdown]
# # Problem 2: Healthcare – Medicine Stock Alert System
#
# ### Problem Statement
# Create a function to monitor medicine stock levels.
#
# ### Rules
# Stock < 10 → Low Stock Alert
#
# Stock ≥ 10 → Stock Sufficient
#
# ### Real-Time Use
#
# Pharmacy management systems
#
# Hospital inventory tracking
#
# ### Hint
#
# Use function
#
# Use conditional logic
#
# ### Expected Output Format
#
# Medicine Stock: 6
#
# Status: Low Stock Alert

# %%
def stock_medicine(stock):
    if(stock < 10):
        print(f"Medicine Stock: {stock} ")
        return "status: Low Stock Alert"
    else:
        print(f"Medicine Stock: {stock}")
        return "status: stock sufficient"

paracetamol = stock_medicine(200)
print(paracetamol)
# Out:
# Medicine Stock: 200
# status: stock sufficient

# %% [markdown]
# # Problem 3: Agriculture – Rainfall Adequacy Checker
#
# ### Problem Statement
#
# Create a function that analyzes seasonal rainfall data.
#
# ### Rules
#
# Calculate average rainfall
#
# Average ≥ required level → Adequate Rainfall
#
# Otherwise → Inadequate Rainfall
#
# ### Real-Time Use
#
# Climate monitoring systems
#
# Irrigation planning tools
#
# ### Hint
#
# Use function
#
# Use loop and math operations
#
# ### Expected Output Format
#
# Average Rainfall: 72
#
# Rainfall Status: Adequate Rainfall

# %%
def rainfall():
    monthly = list(map(int,input("enter monthly rainfall data for 12 months:").split()))
    average = sum(monthly)/len(monthly)
    if(average >= 50):
        return "adequate rainfall"
    else:
        return "inadequate rainfall"
rainfall()
# Out:
# enter monthly rainfall data for 12 months: 12 12 12 12 12 12 12 12 10 76 83 65
# 'inadequate rainfall'

# %% [markdown]
# # Problem 4: Social Media – Duplicate Account Detection
#
# ### Problem Statement
#
# Create a function to detect duplicate usernames in a system.
#
# ### Rules
#
# If duplicates exist → Flag accounts
#
# Else → Accounts are unique
#
# ### Real-Time Use
#
# Platform moderation
#
# Fraud detection systems
#
# ### Hint
# Use function
# ,Use set data structure
#
# ### Expected Output Format
#
# Duplicate Accounts Found: Yes

# %%
def duplicates():
    usernames = ["A","B","C","A"]
    usernames_set = set(usernames)
    if(len(usernames) == len(usernames_set)):
        print("duplicate accounts found: no")
    else:
        print("duplicate accounts found: yes")
duplicates()
# Out:
# duplicate accounts found: yes

# %% [markdown]
# # Problem 5: Healthcare – Appointment Eligibility Checker
#
# ### Problem Statement
#
# Create a function to check whether a patient is eligible for an appointment slot.
#
# ### Rules
#
# Age ≥ 18 → Eligible
#
# Age < 18 → Not Eligible
#
# ### Real-Time Use
#
# Hospital appointment systems
#
# Healthcare portals
#
# ### Hint
#
# Use function
#
# Use condition checks
#
# ### Expected Output Format
#
# Patient Age: 21
#
# Eligibility Status: Eligible

# %%
def hospital_eligible():
    age = int(input("patient age:"))
    if(age >= 18):
        print("eligiblity status:eligible")
    else:
        print("eligibility status:not eligible")
hospital_eligible()
# Out:
# patient age: 21
# eligiblity status:eligible

# %% [markdown]
# # Problem 6: Agriculture – Premium Crop Price Filter
#
# ### Problem Statement
#
# Create a function that filters crop prices above a premium threshold.
#
# ### Rules
#
# Price > ₹2000 → Premium Crop
#
# Else → Regular Crop
#
# ### Real-Time Use
#
# Market analytics
#
# Export pricing systems
#
# ### Hint
#
# Use function
#
# Use list filtering logic
#
# ### Expected Output Format
#
# Premium Crops: [2500, 3200]

# %%
def crops():
    premium_crop = []
    number_crop = int(input("number of crops to categorize:"))
    for i in range(1 , number_crop + 1):
        price = int(input(f"price of crop{i}:"))
        if(price > 2000 ):
            premium_crop.append(price)
    print(f"Premuim crops:{premium_crop}")
crops()
# Out:
# number of crops to categorize: 3
# price of crop1: 6843
# price of crop2: 4343
# price of crop3: 1999
# Premuim crops:[6843, 4343]

# %% [markdown]
# # Problem 7: System Monitoring – Application Health Checker
#
# ### Problem Statement
#
# Create a function to evaluate application health based on error count.
#
# ### Rules
#
# Errors = 0 → Healthy
#
# Errors ≤ 5 → Minor Issues
#
# Errors > 5 → Critical Issues
#
# ### Real-Time Use
#
# System monitoring tools
#
# IT operations dashboards
#
# ### Hint
#
# Use function
#
# Use conditional statements
#
# ### Expected Output Format
#
# Error Count: 7
#
# System Status: Critical Issues

# %%
def system():
    errors_patient = int(input("error count:"))
    if(errors_patient == 0):
        return "System Status:Healthy"
    elif(errors_patient <= 5):
        return "System Status:Minor Issues"
    elif(errors_patient > 5):
        return "System Status:Critical Issues"
aryan = system()
print(aryan)
# Out:
# error count: 5
# System Status:Minor Issues

# %% [markdown]
# # Problem 8: Banking – Daily Transaction Limit Checker
#
# ### Problem Statement
#
# Create a function to validate daily transaction amount.
#
# ### Rules
#
# Daily limit = ₹50,000
#
# Amount within limit → Approved
#
# Amount exceeds limit → Rejected
#
# ### Real-Time Use
#
# Banking systems
#
# Fraud prevention systems
#
# ### Hint
#
# Use function
#
# Use conditional logic
#
# ### Expected Output Format
#
# Transaction Amount: 60000
#
# Transaction Status: Rejected

# %%
def banking():
    daily_limit = 50000
    amount = int(input("transaction amount:"))
    if(amount >= 50000):
        return "transaction status : rejected"
    else:
        return "transaction status : approved"
banking()
# Out:
# transaction amount: 38282
# 'transaction status : approved'

# %% [markdown]
# # Problem 9: E-Learning – Student Attendance Eligibility System
#
# ### Problem Statement
#
# Create a function to calculate attendance percentage and check exam eligibility.
#
# ### Rules
#
# Attendance ≥ 75% → Eligible
#
# Attendance < 75% → Not Eligible
#
# ### Real-Time Use
#
# Learning management systems
#
# Internship tracking platforms
#
# ### Hint
#
# Use function
#
# Use list and loop
#
# ### Expected Output Format
#
# Attendance Percentage: 80.0
#
# Exam Eligibility: Eligible

# %%
def attendance():
    attendance_list = []
    count = 0
    for i in range(1,11):
        attend = input(f"give attendance for day{i} (answer in P or A):")
        attendance_list.append(attend)
        if(attend.lower() == "p"):
            count += 1
    attendance_percentage = (count/len(attendance_list))*100
    print("attendance percentage is:",attendance_percentage)
    if(attendance_percentage >= 75):
        return "Exam Eligiblity:Eligible"
    else:
        return "Exam Eligiblity:Not Eligible"

attendance()
# Out:
# give attendance for day1 (answer in P or A): a
# give attendance for day2 (answer in P or A): a
# give attendance for day3 (answer in P or A): a
# give attendance for day4 (answer in P or A): p
# give attendance for day5 (answer in P or A): p
# give attendance for day6 (answer in P or A): p
# give attendance for day7 (answer in P or A): p
# give attendance for day8 (answer in P or A): p
# give attendance for day9 (answer in P or A): p
# give attendance for day10 (answer in P or A): p
# attendance percentage is: 70.0
# 'Exam Eligiblity:Not Eligible'

# %% [markdown]
# # Problem 10: Smart Electricity Bill Analyzer
#
# ### Problem Statement
#
# You are building a smart electricity billing system for residential users.
#
# Create a function that calculates the electricity bill and classifies usage level based on units consumed.
#
# ### Billing Rules
#
# First 100 units → ₹3 per unit
#
# Next 100 units (101–200) → ₹5 per unit
#
# Above 200 units → ₹7 per unit
#
# ### Usage Classification
#
# Total bill < ₹500 → Low Usage
#
# ₹500 – ₹1500 → Moderate Usage
#
# ₹1500 → High Usage
#
# ### Real-Time Use
#
# Smart meter systems
#
# Electricity board billing software
#
# Energy consumption analytics
#
# ### Hint
#
# Use function to calculate bill
#
# Use conditional logic for slabs
#
# Use return values (bill and usage status)

# %%
def bill_electricity(units):
    if(units <= 100):
        bill = 3*units
        print(f"total bill:{bill}")
    elif(units in range(101,201)):
        bill = 3*100 + 5*(units-100)
        print(f"total bill:{bill}")
    elif(units > 200):
        bill = 3*100+5*100 + 7*(units-2080)
        print(f"total bill:{bill}")
    if(bill < 500):
        print("low usage")
    elif(500<=bill<=1500):
        print("moderate usage")
    else:
        print("high usage")
units = int(input("enter the number of units electricity used:"))
bill_electricity(units)
# Out:
# enter the number of units electricity used: 435
# total bill:-10715
# low usage
